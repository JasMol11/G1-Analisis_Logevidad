# %%
import pandas as pd
import matplotlib.pyplot as plt

# Importar el archivo CSV
file_path = 'CSV_SIN_ANALIZAR/Subalimentacion_Guatemala.csv'
df_subalimentacion_guatemala = pd.read_csv(file_path)  # Asignamos el nombre al DataFrame

# Revisar los datos
print(df_subalimentacion_guatemala.head())

# Configurar el gráfico
plt.figure(figsize=(10, 6))
plt.plot(df_subalimentacion_guatemala['Bianual'], df_subalimentacion_guatemala['value'], 
         marker='o', linestyle='-', color='red', label='Personas en subalimentación')

# Personalizar la gráfica
plt.title('Número de personas en subalimentación en Guatemala (1999-2019)')
plt.xlabel('Periodo Bianual')
plt.ylabel('Número de personas (miles)')
plt.xticks(rotation=45)
plt.grid(visible=True, linestyle='--', alpha=0.7)
plt.legend()

plt.savefig("GRAFICAS/Subalimentacion_Guatemala.png", format="png", dpi=300)
print("Gráfica guardada como GRAFICAS/Subalimentacion_Guatemala.png")

# Mostrar la gráfica
plt.tight_layout()
plt.show()
# Out:
#                                 indicator País__ESTANDAR    Bianual   value  \
# 0  Número de personas en subalimentación.      Guatemala  1999-2001  2389.1
# 1  Número de personas en subalimentación.      Guatemala  2000-2002  2159.0
# 2  Número de personas en subalimentación.      Guatemala  2001-2003  2002.7
# 3  Número de personas en subalimentación.      Guatemala  2002-2004  1975.3
# 4  Número de personas en subalimentación.      Guatemala  2003-2005  2022.1
#
#                                            unit  notes_ids  source_id
# 0  Número absoluto, medida en miles de personas       8605       1371
# 1  Número absoluto, medida en miles de personas       8605       1371
# 2  Número absoluto, medida en miles de personas       8605       1371
# 3  Número absoluto, medida en miles de personas       8605       1371
# 4  Número absoluto, medida en miles de personas       8605       1371
# Gráfica guardada como GRAFICAS/Subalimentacion_Guatemala.png
